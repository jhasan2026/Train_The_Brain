# %%
import pandas as pd

# %% [markdown]
# # 1. Local CSV

# %%
df = pd.read_csv('../../Data/Football_Player_Stats.csv')
df
# Out:
#       Rk               Player Nation   Pos          Squad            Comp  \
# 0      1           Max Aarons    ENG    DF   Norwich City  Premier League
# 1      2     Yunis Abdelhamid    MAR    DF          Reims         Ligue 1
# 2      3    Salis Abdul Samed    GHA    MF  Clermont Foot         Ligue 1
# 3      4      Laurent Abergel    FRA    MF        Lorient         Ligue 1
# 4      5          Charles Abi    FRA    FW  Saint-Étienne         Ligue 1
# ..   ...                  ...    ...   ...            ...             ...
# 495  496  Federico Ceccherini    ITA    DF  Hellas Verona         Serie A
# 496  497           Emil Ceide    NOR  FWDF       Sassuolo         Serie A
# 497  498           Zeki Çelik    TUR    DF          Lille         Ligue 1
# 498  499      Fabien Centonze    FRA    DF           Metz         Ligue 1
# 499  500      Luca Ceppitelli    ITA    DF       Cagliari         Serie A
#
#      Age  Born  MP  CrdY  CrdR  2CrdY  Goals  Shots   SoT  Assists
# ...

# %% [markdown]
# # 2. TSV Data

# %%
tsv_df = pd.read_csv('./../../Data/movie_titles_metadata.tsv', sep='\t')
tsv_df
# Out:
#      m0                     10 things i hate about you  1999  6.90   62847  \
# 0    m1                     1492: conquest of paradise  1992   6.2   10421
# 1    m2                                     15 minutes  2001   6.1   25854
# 2    m3                          2001: a space odyssey  1968   8.4  163227
# 3    m4                                        48 hrs.  1982   6.9   22289
# 4    m5                              the fifth element  1997   7.5  133756
# 5    m6                                            8mm  1999   6.3   48212
# 6    m7  a nightmare on elm street 4: the dream master  1988   5.2   13590
# 7    m8     a nightmare on elm street: the dream child  1989   4.7   11092
# 8    m9                           the atomic submarine  1959   4.9     513
# 9   m10                                     affliction  1997   6.9    7252
# 10  m11                                  air force one  1997   6.3   61978
# ...

# %% [markdown]
# # 3. Make title

# %%
tsv_df = pd.read_csv('./../../Data/movie_titles_metadata.tsv', sep='\t', names=['m','Movie','year','rating','vote','Genre'])
tsv_df
# Out:
#       m                                          Movie  year  rating    vote  \
# 0    m0                     10 things i hate about you  1999     6.9   62847
# 1    m1                     1492: conquest of paradise  1992     6.2   10421
# 2    m2                                     15 minutes  2001     6.1   25854
# 3    m3                          2001: a space odyssey  1968     8.4  163227
# 4    m4                                        48 hrs.  1982     6.9   22289
# 5    m5                              the fifth element  1997     7.5  133756
# 6    m6                                            8mm  1999     6.3   48212
# 7    m7  a nightmare on elm street 4: the dream master  1988     5.2   13590
# 8    m8     a nightmare on elm street: the dream child  1989     4.7   11092
# 9    m9                           the atomic submarine  1959     4.9     513
# 10  m10                                     affliction  1997     6.9    7252
# ...

# %% [markdown]
# # 4. Make a col as index

# %%
df = pd.read_csv('../../Data/Football_Player_Stats.csv', index_col=['Player'])
df
# Out:
#                       Rk Nation   Pos          Squad            Comp  Age  \
# Player
# Max Aarons             1    ENG    DF   Norwich City  Premier League   22
# Yunis Abdelhamid       2    MAR    DF          Reims         Ligue 1   34
# Salis Abdul Samed      3    GHA    MF  Clermont Foot         Ligue 1   22
# Laurent Abergel        4    FRA    MF        Lorient         Ligue 1   29
# Charles Abi            5    FRA    FW  Saint-Étienne         Ligue 1   22
# ...                  ...    ...   ...            ...             ...  ...
# Federico Ceccherini  496    ITA    DF  Hellas Verona         Serie A   30
# Emil Ceide           497    NOR  FWDF       Sassuolo         Serie A   20
# Zeki Çelik           498    TUR    DF          Lille         Ligue 1   25
# Fabien Centonze      499    FRA    DF           Metz         Ligue 1   26
# Luca Ceppitelli      500    ITA    DF       Cagliari         Serie A   32
#
# ...

# %% [markdown]
# # 5. First data as column

# %%
df = pd.read_csv('../../Data/test.csv',header=1)
df
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %% [markdown]
# # 6. Selective Column

# %%
df = pd.read_csv('../../Data/Football_Player_Stats.csv', usecols=['Player','Pos','Age'])
df
# Out:
#                   Player   Pos  Age
# 0             Max Aarons    DF   22
# 1       Yunis Abdelhamid    DF   34
# 2      Salis Abdul Samed    MF   22
# 3        Laurent Abergel    MF   29
# 4            Charles Abi    FW   22
# ..                   ...   ...  ...
# 495  Federico Ceccherini    DF   30
# 496           Emil Ceide  FWDF   20
# 497           Zeki Çelik    DF   25
# 498      Fabien Centonze    DF   26
# 499      Luca Ceppitelli    DF   32
#
# [500 rows x 3 columns]

# %% [markdown]
# # 7. Skip Row

# %%
df = pd.read_csv('../../Data/Football_Player_Stats.csv', skiprows=[1,2,3])
df
# Out:
#       Rk               Player Nation   Pos           Squad        Comp  Age  \
# 0      4      Laurent Abergel    FRA    MF         Lorient     Ligue 1   29
# 1      5          Charles Abi    FRA    FW   Saint-Étienne     Ligue 1   22
# 2      6       Dickson Abiama    NGA    FW  Greuther Fürth  Bundesliga   23
# 3      7       Matthis Abline    FRA    FW          Rennes     Ligue 1   19
# 4      8        Tammy Abraham    ENG    FW            Roma     Serie A   24
# ..   ...                  ...    ...   ...             ...         ...  ...
# 492  496  Federico Ceccherini    ITA    DF   Hellas Verona     Serie A   30
# 493  497           Emil Ceide    NOR  FWDF        Sassuolo     Serie A   20
# 494  498           Zeki Çelik    TUR    DF           Lille     Ligue 1   25
# 495  499      Fabien Centonze    FRA    DF            Metz     Ligue 1   26
# 496  500      Luca Ceppitelli    ITA    DF        Cagliari     Serie A   32
#
# ...

# %%
df = pd.read_csv('../../Data/Football_Player_Stats.csv', skiprows=50)
df
# Out:
#       50         Lucas Alario  ARG    FW      Leverkusen      Bundesliga  29  \
# 0     51           Jordi Alba  ESP    DF       Barcelona         La Liga  33
# 1     52         Josué Albert  GUF    DF   Clermont Foot         Ligue 1  30
# 2     53         Luis Alberto  ESP    MF           Lazio         Serie A  29
# 3     54          Raúl Albiol  ESP    DF      Villarreal         La Liga  36
# 4     55      Marc Albrighton  ENG  FWDF  Leicester City  Premier League  32
# ..   ...                  ...  ...   ...             ...             ...  ..
# 445  496  Federico Ceccherini  ITA    DF   Hellas Verona         Serie A  30
# 446  497           Emil Ceide  NOR  FWDF        Sassuolo         Serie A  20
# 447  498           Zeki Çelik  TUR    DF           Lille         Ligue 1  25
# 448  499      Fabien Centonze  FRA    DF            Metz         Ligue 1  26
# 449  500      Luca Ceppitelli  ITA    DF        Cagliari         Serie A  32
#
# ...

# %% [markdown]
# # 8. Utf encoding

# %%
df = pd.read_csv('../../Data/zomato.csv')
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv('../../Data/zomato.csv')
#       2 df
#
# File D:\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.read_csv('../../Data/zomato.csv',encoding='latin-1')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# # 9. Dtype & Date time type

# %%
df = pd.read_csv('../../Data/IPL Matches 2008-2020.csv',dtype={'neutral_venue':float},parse_dates=['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    float64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...
