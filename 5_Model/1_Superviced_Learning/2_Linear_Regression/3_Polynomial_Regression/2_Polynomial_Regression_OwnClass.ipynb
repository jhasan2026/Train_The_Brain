# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = 8 * np.random.rand(1000) - 4
y = (0.8 * X**2) + (0.7 * X) + 2 + np.random.randn(1000)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800,), (200,), (800,), (200,))

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

# %%
plt.plot(X_train,y_train,'b.')

# %% [markdown]
# # Using Polynomial

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
class PolynomialRegression:
    def __init__(self):
        self.polynomail = None
        
    def fit(self,X_train, y_train, degree=2):
        poly_trf = Pipeline([
            ('polynomial_trf',PolynomialFeatures(degree=degree,include_bias=True)),
            ('scaler',StandardScaler()),
            ('regression',LinearRegression())
        ])
        
        self.polynomail =poly_trf.fit(X_train, y_train)
        
    def predict(self,X_test):
        return self.polynomail.predict(X_test)

# %%
polyReg = PolynomialRegression()

# %%
polyReg.fit(X_train,y_train)

# %%
y_pred = polyReg.predict(X_test)
y_pred
# Out:
# array([11.9388829 , 11.70379347,  3.11204584,  1.82710958,  8.3991072 ,
#         2.94514544,  1.84307436, 10.41911534,  2.94473761,  8.50023895,
#         2.09766306,  2.83799402, 11.13189186,  8.36177334,  6.27202198,
#         2.56067173,  2.21764784,  1.95238918,  5.5513043 ,  2.68231261,
#         4.33073578,  3.64444318,  2.50498193,  9.37820311,  3.81069533,
#        10.96826416,  2.54032527,  2.02872424, 10.30786494,  2.83970763,
#         1.82724663,  7.65182812,  1.92627731,  6.8790851 ,  3.98017055,
#         6.48967642,  8.60868041,  3.14182488,  1.89044169,  2.65273615,
#         1.84031289,  3.75768593,  2.57990466,  2.38129294,  6.01257935,
#         2.34029773,  3.93620825, 11.54243885,  6.98484324,  2.28568439,
#        12.14319865,  8.99800686,  5.99596708,  6.11788238,  9.00508154,
#         3.74978362,  5.71855592,  6.05281213,  7.26897504,  1.83738941,
#         8.89945631,  2.22608158,  8.50620823,  2.35540452,  6.553404  ,
# ...

# %%
from sklearn.metrics import r2_score
