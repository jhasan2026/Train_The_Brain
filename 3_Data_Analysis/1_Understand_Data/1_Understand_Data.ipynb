# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../Data/Football_Player_Stats.csv')
df
# Out:
#       Rk               Player Nation   Pos          Squad            Comp  \
# 0      1           Max Aarons    ENG    DF   Norwich City  Premier League
# 1      2     Yunis Abdelhamid    MAR    DF          Reims         Ligue 1
# 2      3    Salis Abdul Samed    GHA    MF  Clermont Foot         Ligue 1
# 3      4      Laurent Abergel    FRA    MF        Lorient         Ligue 1
# 4      5          Charles Abi    FRA    FW  Saint-Étienne         Ligue 1
# ..   ...                  ...    ...   ...            ...             ...
# 495  496  Federico Ceccherini    ITA    DF  Hellas Verona         Serie A
# 496  497           Emil Ceide    NOR  FWDF       Sassuolo         Serie A
# 497  498           Zeki Çelik    TUR    DF          Lille         Ligue 1
# 498  499      Fabien Centonze    FRA    DF           Metz         Ligue 1
# 499  500      Luca Ceppitelli    ITA    DF       Cagliari         Serie A
#
#      Age  Born  MP  CrdY  CrdR  2CrdY  Goals  Shots   SoT  Assists
# ...

# %% [markdown]
# # 1. How big the data is

# %%
df.shape
# Out:
# (500, 16)

# %% [markdown]
# # 2. Data look like

# %%
df.sample(10)
# Out:
#       Rk             Player Nation   Pos          Squad            Comp  Age  \
# 268  269    Darío Benedetto    ARG  FWMF      Marseille         Ligue 1   32
# 368  369    Lilian Brassier    FRA    DF          Brest         Ligue 1   22
# 481  482  Francesco Cassata    ITA    MF          Genoa         Serie A   24
# 103  104  Josep Antoni Gayá    ESP    DF       Mallorca         La Liga   21
# 188  189    Folarin Balogun    ENG    FW        Arsenal  Premier League   20
# 202  203        Enis Bardhi    MKD  MFFW        Levante         La Liga   26
# 104  105    Michail Antonio    JAM    FW       West Ham  Premier League   32
# 14    15        Tyler Adams    USA    MF     RB Leipzig      Bundesliga   23
# 171  172       Stefan Bajic    FRA    GK  Saint-Étienne         Ligue 1   20
# 457  458   Pierrick Capelle    FRA  MFDF         Angers         Ligue 1   35
#
#      Born  MP  CrdY  CrdR  2CrdY  Goals  Shots   SoT  Assists
# ...

# %% [markdown]
# # 3. Data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rk       500 non-null    int64
#  1   Player   500 non-null    object
#  2   Nation   500 non-null    object
#  3   Pos      500 non-null    object
#  4   Squad    500 non-null    object
#  5   Comp     500 non-null    object
#  6   Age      500 non-null    int64
#  7   Born     500 non-null    int64
#  8   MP       500 non-null    int64
#  9   CrdY     500 non-null    float64
#  10  CrdR     500 non-null    float64
#  11  2CrdY    500 non-null    float64
#  12  Goals    500 non-null    float64
#  13  Shots    500 non-null    float64
#  14  SoT      500 non-null    float64
#  15  Assists  500 non-null    float64
# dtypes: float64(7), int64(4), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# # 4. Missing value

# %%
df.isnull().sum()
# Out:
# Rk         0
# Player     0
# Nation     0
# Pos        0
# Squad      0
# Comp       0
# Age        0
# Born       0
# MP         0
# CrdY       0
# CrdR       0
# 2CrdY      0
# Goals      0
# Shots      0
# SoT        0
# Assists    0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# Rk         0.0
# Player     0.0
# Nation     0.0
# Pos        0.0
# Squad      0.0
# Comp       0.0
# Age        0.0
# Born       0.0
# MP         0.0
# CrdY       0.0
# CrdR       0.0
# 2CrdY      0.0
# Goals      0.0
# Shots      0.0
# SoT        0.0
# Assists    0.0
# dtype: float64

# %% [markdown]
# # 5. All statistical info

# %%
df.describe()
# Out:
#                Rk       Age         Born          MP        CrdY        CrdR  \
# count  500.000000  500.0000   500.000000  500.000000  500.000000  500.000000
# mean   250.500000   26.0840  1995.428000   18.842000    0.200180    0.007100
# std    144.481833    4.6661     4.651461   11.770051    0.226039    0.026744
# min      1.000000   16.0000  1981.000000    1.000000    0.000000    0.000000
# 25%    125.750000   22.7500  1992.000000    8.000000    0.000000    0.000000
# 50%    250.500000   26.0000  1996.000000   19.000000    0.160000    0.000000
# 75%    375.250000   30.0000  1999.000000   30.000000    0.290000    0.000000
# max    500.000000   40.0000  2005.000000   38.000000    1.670000    0.230000
#
#             2CrdY       Goals       Shots         SoT     Assists
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     0.003320    0.109280    1.202860    0.393340    0.088220
# std      0.019113    0.228774    1.430507    0.674536    0.257428
# ...

# %%
# all numerical data
df[['Age', 'Born', 'MP','CrdY', 'CrdR', '2CrdY', 'Goals', 'Shots', 'SoT', 'Assists']].corr()
# Out:
#               Age      Born        MP      CrdY      CrdR     2CrdY     Goals  \
# Age      1.000000 -0.994237  0.231658  0.071522  0.040338 -0.010549  0.093172
# Born    -0.994237  1.000000 -0.234750 -0.064687 -0.033821  0.022531 -0.102459
# MP       0.231658 -0.234750  1.000000  0.072383  0.051765  0.044651  0.138424
# CrdY     0.071522 -0.064687  0.072383  1.000000  0.152017  0.212959 -0.103965
# CrdR     0.040338 -0.033821  0.051765  0.152017  1.000000  0.712031 -0.021370
# 2CrdY   -0.010549  0.022531  0.044651  0.212959  0.712031  1.000000 -0.021360
# Goals    0.093172 -0.102459  0.138424 -0.103965 -0.021370 -0.021360  1.000000
# Shots    0.052384 -0.063211  0.045689 -0.016104 -0.055817 -0.015102  0.426449
# SoT     -0.016816  0.007630  0.056582 -0.056160 -0.053174 -0.030738  0.455973
# Assists  0.015123 -0.023078  0.050967 -0.036669 -0.008145  0.007924  0.068899
#
#             Shots       SoT   Assists
# Age      0.052384 -0.016816  0.015123
# ...

# %% [markdown]
# # 6. Duplicate value check

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0
